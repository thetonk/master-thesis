# %% [markdown]
# # IoT to IDS transfer learning results
#
# Tested again zero-shot and few shot learning. Experiment configuration:
# - Few shot samples per class: 1000
# - Transformer training: 30 epochs with early stop
# - LSTM training: 5 epochs with early stop
#
# The experiments tested the cases where network specific features exist in datasets, and when they are removed from datasets. Finally, the dataset was created by randomly sampling by equal amounts from all datasets, while preserving class balance (50% benign, 50% malicious samples)

# %% [markdown]
# ## Loading the required Python packages for processing
# Loading global functions and overall useful processing functions as well.

# %%
import pandas as pd
import os

RESULTS_DIR = "../results/reports"

# %% [markdown]
# ## Few-shot transfer learning
# ### With network specific features

# %%
transformer_df = pd.read_csv(os.path.join(RESULTS_DIR, "transformer/few_shot/1000_samples/iot_vs_ids/with_network_specific_features/30_epochs_early_stop/binary_metrics/results_transformer_TL_few_shot.csv"))

lstm_df = pd.read_csv(os.path.join(RESULTS_DIR, "lstm/few_shot/1000_samples/iot_vs_ids/with_network_specific_features/5_epochs_early_stop/binary_metrics/results_lstm_TL_few_shot.csv"))
transformer_iot_ids = transformer_df.loc[transformer_df["Fold #"] == 1]
transformer_ids_iot = transformer_df.loc[transformer_df["Fold #"] == 2]
lstm_iot_ids = lstm_df.loc[transformer_df["Fold #"] == 1]
lstm_ids_iot = lstm_df.loc[transformer_df["Fold #"] == 2]

data = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean()],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean()]
]

data_no_mean = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean()],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean()]
]

metrics_df = pd.DataFrame(data_no_mean, columns=["Transformer", "LSTM"], index=["IoT to IDS", "IDS to IoT"])

ax = metrics_df.plot(kind='bar', rot=0)
ax.set_title("Transfer learning by data origin")
fig = ax.get_figure()
fig.savefig("iot_vs_ids_few_shot_nomean.pdf")

# %% [markdown]
# ### Without network specific features

# %%
transformer_df = pd.read_csv(os.path.join(RESULTS_DIR, "transformer/few_shot/1000_samples/iot_vs_ids/without_network_specific_features_improved/30_epochs_early_stop/binary_metrics/results_transformer_TL_removed_few_shot.csv"))

lstm_df = pd.read_csv(os.path.join(RESULTS_DIR, "lstm/few_shot/1000_samples/iot_vs_ids/without_network_specific_features_improved/5_epochs_early_stop/binary_metrics/results_lstm_TL_removed_few_shot.csv"))
transformer_iot_ids = transformer_df.loc[transformer_df["Fold #"] == 1]
transformer_ids_iot = transformer_df.loc[transformer_df["Fold #"] == 2]
lstm_iot_ids = lstm_df.loc[transformer_df["Fold #"] == 1]
lstm_ids_iot = lstm_df.loc[transformer_df["Fold #"] == 2]

data = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean(),
     (transformer_iot_ids["Accuracy"].mean() + lstm_iot_ids["Accuracy"].mean()) / 2],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean(),
     (transformer_ids_iot["Accuracy"].mean() + lstm_ids_iot["Accuracy"].mean()) / 2]
]

data_no_mean = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean()],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean()]
]

metrics_df = pd.DataFrame(data_no_mean, columns=["Transformer", "LSTM"], index=["IoT to IDS", "IDS to IoT"])

ax = metrics_df.plot(kind='bar', rot=0)
ax.set_title("Transfer learning by data origin")
fig = ax.get_figure()
fig.savefig("iot_vs_ids_few_shot_removed_nomean.pdf")

# %% [markdown]
# ## Zero shot transfer learning
# ### With network specific features

# %%
transformer_df = pd.read_csv(os.path.join(RESULTS_DIR, "transformer/zero_shot/iot_vs_ids/with_network_specific_features/30_epochs_early_stop/binary_metrics/results_transformer_TL_zero_shot.csv"))

lstm_df = pd.read_csv(os.path.join(RESULTS_DIR, "lstm/zero_shot/iot_vs_ids/with_network_specific_features/5_epochs_early_stop/binary_metrics/results_lstm_TL_zero_shot.csv"))
transformer_iot_ids = transformer_df.loc[transformer_df["Fold #"] == 1]
transformer_ids_iot = transformer_df.loc[transformer_df["Fold #"] == 2]
lstm_iot_ids = lstm_df.loc[transformer_df["Fold #"] == 1]
lstm_ids_iot = lstm_df.loc[transformer_df["Fold #"] == 2]

data = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean(),
     (transformer_iot_ids["Accuracy"].mean() + lstm_iot_ids["Accuracy"].mean()) / 2],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean(),
     (transformer_ids_iot["Accuracy"].mean() + lstm_ids_iot["Accuracy"].mean()) / 2]
]

data_no_mean = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean()],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean()]
]

metrics_df = pd.DataFrame(data_no_mean, columns=["Transformer", "LSTM"], index=["IoT to IDS", "IDS to IoT"])

ax = metrics_df.plot(kind='bar', rot=0)
ax.set_title("Transfer learning by data origin")
fig = ax.get_figure()
fig.savefig("iot_vs_ids_zero_shot.pdf")

# %% [markdown]
# ### Without network specific features

# %%
transformer_df = pd.read_csv(os.path.join(RESULTS_DIR, "transformer/zero_shot/iot_vs_ids/without_network_specific_features_improved/30_epochs_early_stop/binary_metrics/results_transformer_TL_removed_zero_shot.csv"))

lstm_df = pd.read_csv(os.path.join(RESULTS_DIR, "lstm/zero_shot/iot_vs_ids/without_network_specific_features_improved/5_epochs_early_stop/binary_metrics/results_lstm_TL_removed_zero_shot.csv"))
transformer_iot_ids = transformer_df.loc[transformer_df["Fold #"] == 1]
transformer_ids_iot = transformer_df.loc[transformer_df["Fold #"] == 2]
lstm_iot_ids = lstm_df.loc[transformer_df["Fold #"] == 1]
lstm_ids_iot = lstm_df.loc[transformer_df["Fold #"] == 2]

data = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean(),
     (transformer_iot_ids["Accuracy"].mean() + lstm_iot_ids["Accuracy"].mean()) / 2],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean(),
     (transformer_ids_iot["Accuracy"].mean() + lstm_ids_iot["Accuracy"].mean()) / 2]
]

data_no_mean = [
    [transformer_iot_ids["Accuracy"].mean(), lstm_iot_ids["Accuracy"].mean()],
    [transformer_ids_iot["Accuracy"].mean(), lstm_ids_iot["Accuracy"].mean()]
]

metrics_df = pd.DataFrame(data_no_mean, columns=["Transformer", "LSTM"], index=["IoT to IDS", "IDS to IoT"])

ax = metrics_df.plot(kind='bar', rot=0)
ax.set_title("Transfer learning by data origin")
fig = ax.get_figure()
fig.savefig("iot_vs_ids_zero_shot_removed.pdf")
